# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (2.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.23.1)
# Requirement already satisfied: tensorboard~=2.6 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: libclang>=9.0.1 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: six>=1.12.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (4.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: absl-py>=0.4.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: numpy>=1.14.5 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: h5py>=2.9.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.27.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (0.4.5)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (61.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/param-mu-scom/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_222845/4250752346.py in <cell line: 1>()
# ----> 1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import Dense, LSTM
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/__init__.py in <module>
#      82 from tensorflow.python import data
#      83 from tensorflow.python import distribute
# ---> 84 from tensorflow.python import keras
#      85 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      86 from tensorflow.python.layers import layers
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py in <module>
#      25
#      26 # See b/110718070#comment18 for more details about this import.
# ---> 27 from tensorflow.python.keras import models
#      28
#      29 from tensorflow.python.keras.engine.input_layer import Input
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/models.py in <module>
#      22 from tensorflow.python.framework import ops
#      23 from tensorflow.python.keras import backend as K
# ---> 24 from tensorflow.python.keras import metrics as metrics_module
#      25 from tensorflow.python.keras import optimizers
#      26 from tensorflow.python.keras.engine import network
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/metrics.py in <module>
#      35 from tensorflow.python.framework import tensor_spec
#      36 from tensorflow.python.keras import backend as K
# ---> 37 from tensorflow.python.keras.engine import base_layer
#      38 from tensorflow.python.keras.engine import base_layer_utils
#      39 from tensorflow.python.keras.losses import binary_crossentropy
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in <module>
#      49 from tensorflow.python.keras import backend
#      50 from tensorflow.python.keras import constraints
# ---> 51 from tensorflow.python.keras import initializers
#      52 from tensorflow.python.keras import regularizers
#      53 from tensorflow.python.keras.engine import base_layer_utils
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/initializers/__init__.py in <module>
#     120 # from ALL_OBJECTS. We make no guarantees as to whether these objects will
#     121 # using their correct version.
# --> 122 populate_deserializable_objects()
#     123 globals().update(LOCAL.ALL_OBJECTS)
#     124
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/initializers/__init__.py in populate_deserializable_objects()
#      78     v2_objs = {}
#      79     base_cls = initializers_v2.Initializer
# ---> 80     generic_utils.populate_dict_with_module_objects(
#      81         v2_objs,
#      82         [initializers_v2],
#
# AttributeError: module 'tensorflow.python.keras.utils.generic_utils' has no attribute 'populate_dict_with_module_objects'

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_222845/2230192785.py in <cell line: 1>()
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Dense, LSTM
#
# ~/anaconda3/lib/python3.8/site-packages/keras/__init__.py in <module>
#      19 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python import tf2
#      22 from keras import distribute
#      23
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/__init__.py in <module>
#      82 from tensorflow.python import data
#      83 from tensorflow.python import distribute
# ---> 84 from tensorflow.python import keras
#      85 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      86 from tensorflow.python.layers import layers
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py in <module>
#      25
#      26 # See b/110718070#comment18 for more details about this import.
# ---> 27 from tensorflow.python.keras import models
#      28
#      29 from tensorflow.python.keras.engine.input_layer import Input
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/models.py in <module>
#      22 from tensorflow.python.framework import ops
#      23 from tensorflow.python.keras import backend as K
# ---> 24 from tensorflow.python.keras import metrics as metrics_module
#      25 from tensorflow.python.keras import optimizers
#      26 from tensorflow.python.keras.engine import network
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/metrics.py in <module>
#      35 from tensorflow.python.framework import tensor_spec
#      36 from tensorflow.python.keras import backend as K
# ---> 37 from tensorflow.python.keras.engine import base_layer
#      38 from tensorflow.python.keras.engine import base_layer_utils
#      39 from tensorflow.python.keras.losses import binary_crossentropy
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in <module>
#      49 from tensorflow.python.keras import backend
#      50 from tensorflow.python.keras import constraints
# ---> 51 from tensorflow.python.keras import initializers
#      52 from tensorflow.python.keras import regularizers
#      53 from tensorflow.python.keras.engine import base_layer_utils
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/initializers/__init__.py in <module>
#     120 # from ALL_OBJECTS. We make no guarantees as to whether these objects will
#     121 # using their correct version.
# --> 122 populate_deserializable_objects()
#     123 globals().update(LOCAL.ALL_OBJECTS)
#     124
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/initializers/__init__.py in populate_deserializable_objects()
#      78     v2_objs = {}
#      79     base_cls = initializers_v2.Initializer
# ---> 80     generic_utils.populate_dict_with_module_objects(
#      81         v2_objs,
#      82         [initializers_v2],
#
# AttributeError: module 'tensorflow.python.keras.utils.generic_utils' has no attribute 'populate_dict_with_module_objects'

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_222845/3793406994.py in <cell line: 1>()
# ----> 1 import tensorflow as tf
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/__init__.py in <module>
#      82 from tensorflow.python import data
#      83 from tensorflow.python import distribute
# ---> 84 from tensorflow.python import keras
#      85 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      86 from tensorflow.python.layers import layers
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py in <module>
#      25
#      26 # See b/110718070#comment18 for more details about this import.
# ---> 27 from tensorflow.python.keras import models
#      28
#      29 from tensorflow.python.keras.engine.input_layer import Input
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/models.py in <module>
#      22 from tensorflow.python.framework import ops
#      23 from tensorflow.python.keras import backend as K
# ---> 24 from tensorflow.python.keras import metrics as metrics_module
#      25 from tensorflow.python.keras import optimizers
#      26 from tensorflow.python.keras.engine import network
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/metrics.py in <module>
#      35 from tensorflow.python.framework import tensor_spec
#      36 from tensorflow.python.keras import backend as K
# ---> 37 from tensorflow.python.keras.engine import base_layer
#      38 from tensorflow.python.keras.engine import base_layer_utils
#      39 from tensorflow.python.keras.losses import binary_crossentropy
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in <module>
#      49 from tensorflow.python.keras import backend
#      50 from tensorflow.python.keras import constraints
# ---> 51 from tensorflow.python.keras import initializers
#      52 from tensorflow.python.keras import regularizers
#      53 from tensorflow.python.keras.engine import base_layer_utils
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/initializers/__init__.py in <module>
#     120 # from ALL_OBJECTS. We make no guarantees as to whether these objects will
#     121 # using their correct version.
# --> 122 populate_deserializable_objects()
#     123 globals().update(LOCAL.ALL_OBJECTS)
#     124
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/initializers/__init__.py in populate_deserializable_objects()
#      78     v2_objs = {}
#      79     base_cls = initializers_v2.Initializer
# ---> 80     generic_utils.populate_dict_with_module_objects(
#      81         v2_objs,
#      82         [initializers_v2],
#
# AttributeError: module 'tensorflow.python.keras.utils.generic_utils' has no attribute 'populate_dict_with_module_objects'

# %%
from tensorflow.python.keras import metrics as metrics_module
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_222845/616933212.py in <cell line: 1>()
# ----> 1 from tensorflow.python.keras import metrics as metrics_module
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/__init__.py in <module>
#      82 from tensorflow.python import data
#      83 from tensorflow.python import distribute
# ---> 84 from tensorflow.python import keras
#      85 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      86 from tensorflow.python.layers import layers
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py in <module>
#      25
#      26 # See b/110718070#comment18 for more details about this import.
# ---> 27 from tensorflow.python.keras import models
#      28
#      29 from tensorflow.python.keras.engine.input_layer import Input
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/models.py in <module>
#      22 from tensorflow.python.framework import ops
#      23 from tensorflow.python.keras import backend as K
# ---> 24 from tensorflow.python.keras import metrics as metrics_module
#      25 from tensorflow.python.keras import optimizers
#      26 from tensorflow.python.keras.engine import network
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/metrics.py in <module>
#      35 from tensorflow.python.framework import tensor_spec
#      36 from tensorflow.python.keras import backend as K
# ---> 37 from tensorflow.python.keras.engine import base_layer
#      38 from tensorflow.python.keras.engine import base_layer_utils
#      39 from tensorflow.python.keras.losses import binary_crossentropy
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in <module>
#      49 from tensorflow.python.keras import backend
#      50 from tensorflow.python.keras import constraints
# ---> 51 from tensorflow.python.keras import initializers
#      52 from tensorflow.python.keras import regularizers
#      53 from tensorflow.python.keras.engine import base_layer_utils
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/initializers/__init__.py in <module>
#     120 # from ALL_OBJECTS. We make no guarantees as to whether these objects will
#     121 # using their correct version.
# --> 122 populate_deserializable_objects()
#     123 globals().update(LOCAL.ALL_OBJECTS)
#     124
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/initializers/__init__.py in populate_deserializable_objects()
#      78     v2_objs = {}
#      79     base_cls = initializers_v2.Initializer
# ---> 80     generic_utils.populate_dict_with_module_objects(
#      81         v2_objs,
#      82         [initializers_v2],
#
# AttributeError: module 'tensorflow.python.keras.utils.generic_utils' has no attribute 'populate_dict_with_module_objects'

# %%
from tensorflow.python.keras.engine import base_layer
from tensorflow.python.keras import initializers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_222845/3704056850.py in <cell line: 1>()
# ----> 1 from tensorflow.python.keras.engine import base_layer
#       2 from tensorflow.python.keras import initializers
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in <module>
#      47 from tensorflow.python.framework import tensor_spec
#      48 from tensorflow.python.framework import tensor_util
# ---> 49 from tensorflow.python.keras import backend
#      50 from tensorflow.python.keras import constraints
#      51 from tensorflow.python.keras import initializers
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/__init__.py in <module>
#      82 from tensorflow.python import data
#      83 from tensorflow.python import distribute
# ---> 84 from tensorflow.python import keras
#      85 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      86 from tensorflow.python.layers import layers
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/__init__.py in <module>
#      25
#      26 # See b/110718070#comment18 for more details about this import.
# ---> 27 from tensorflow.python.keras import models
#      28
#      29 from tensorflow.python.keras.engine.input_layer import Input
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/models.py in <module>
#      22 from tensorflow.python.framework import ops
#      23 from tensorflow.python.keras import backend as K
# ---> 24 from tensorflow.python.keras import metrics as metrics_module
#      25 from tensorflow.python.keras import optimizers
#      26 from tensorflow.python.keras.engine import network
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/metrics.py in <module>
#      50 from tensorflow.python.keras.losses import sparse_categorical_crossentropy
#      51 from tensorflow.python.keras.losses import squared_hinge
# ---> 52 from tensorflow.python.keras.saving.saved_model import metric_serialization
#      53 from tensorflow.python.keras.utils import metrics_utils
#      54 from tensorflow.python.keras.utils.generic_utils import deserialize_keras_object
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/metric_serialization.py in <module>
#      19 from __future__ import print_function
#      20
# ---> 21 from tensorflow.python.keras.saving.saved_model import layer_serialization
#      22 from tensorflow.python.training.tracking import data_structures
#      23
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/layer_serialization.py in <module>
#      22 from tensorflow.python.keras.saving.saved_model import base_serialization
#      23 from tensorflow.python.keras.saving.saved_model import constants
# ---> 24 from tensorflow.python.keras.saving.saved_model import save_impl
#      25 from tensorflow.python.keras.saving.saved_model import serialized_attributes
#      26 from tensorflow.python.keras.utils import generic_utils
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/save_impl.py in <module>
#      32 from tensorflow.python.keras.engine import base_layer_utils
#      33 from tensorflow.python.keras.engine import input_spec
# ---> 34 from tensorflow.python.keras.saving import saving_utils
#      35 from tensorflow.python.keras.saving.saved_model import constants
#      36 from tensorflow.python.keras.saving.saved_model import load as keras_load
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/saving/saving_utils.py in <module>
#      26 from tensorflow.python.keras import backend as K
#      27 from tensorflow.python.keras import losses
# ---> 28 from tensorflow.python.keras import optimizers
#      29 from tensorflow.python.keras.engine import base_layer_utils
#      30 from tensorflow.python.keras.utils import generic_utils
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizers.py in <module>
#      25 from tensorflow.python.framework import ops
#      26 from tensorflow.python.keras import backend as K
# ---> 27 from tensorflow.python.keras.optimizer_v2 import adadelta as adadelta_v2
#      28 from tensorflow.python.keras.optimizer_v2 import adagrad as adagrad_v2
#      29 from tensorflow.python.keras.optimizer_v2 import adam as adam_v2
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/adadelta.py in <module>
#      23 from tensorflow.python.framework import ops
#      24 from tensorflow.python.keras import backend_config
# ---> 25 from tensorflow.python.keras.optimizer_v2 import optimizer_v2
#      26 from tensorflow.python.ops import array_ops
#      27 from tensorflow.python.training import training_ops
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in <module>
#      36 from tensorflow.python.framework import tensor_util
#      37 from tensorflow.python.keras import backend
# ---> 38 from tensorflow.python.keras import initializers
#      39 from tensorflow.python.keras.engine import base_layer_utils
#      40 from tensorflow.python.keras.optimizer_v2 import learning_rate_schedule
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/initializers/__init__.py in <module>
#     120 # from ALL_OBJECTS. We make no guarantees as to whether these objects will
#     121 # using their correct version.
# --> 122 populate_deserializable_objects()
#     123 globals().update(LOCAL.ALL_OBJECTS)
#     124
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/initializers/__init__.py in populate_deserializable_objects()
#      78     v2_objs = {}
#      79     base_cls = initializers_v2.Initializer
# ---> 80     generic_utils.populate_dict_with_module_objects(
#      81         v2_objs,
#      82         [initializers_v2],
#
# AttributeError: module 'tensorflow.python.keras.utils.generic_utils' has no attribute 'populate_dict_with_module_objects'
